# %% [markdown]
# <a href="https://colab.research.google.com/github/Jayashree-DataScience/Python_codes/blob/main/Python_Assignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#solution 1
str="*"
for i in range(1,6):
  print(str*i)
for j in range(4,0,-1):
  print(str*j)
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
word1=input("Enter a word ")
rev_word=word1[::-1]
print("Reverse of the word {} is {}".format(word1,rev_word))
# Out:
# Enter a word Jay
# Reverse of the word Jay is yaJ
